# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from merlin import post
import itertools
import os

path = '/Users/bnowicki/Documents/Scratch/analysis_fid/maindir/'

simpost = post.Simulation_Post_Analysis('CC-Fiducial', path)

df = simpost.populate_table()
# Out:
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_*_sim_info.txt
# 163
# 00304
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00304_line_luminosity.txt
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00304_field_info.txt
# 00305
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00305_line_luminosity.txt
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00305_field_info.txt
# 00306
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00306_line_luminosity.txt
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00306_field_info.txt
# 00307
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00307_line_luminosity.txt
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00307_field_info.txt
# 00308
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00308_line_luminosity.txt
# /Users/bnowicki/Documents/Scratch/analysis_fid/maindir/output_00308_field_info.txt
# ...

# %%
print(df.shape)
print(df.columns)
df.head(10)
# Out:
# (163, 285)
# Index(['output_id', 'current_time', 'domain_dimensions', 'domain_left_edge',
#        'domain_right_edge', 'cosmological_simulation', 'current_redshift',
#        'omega_lambda', 'omega_matter', 'omega_radiation',
#        ...
#        '('gas', 'luminosity_S2_6716.44A')_agg',
#        '('gas', 'flux_S2_6730.82A')_min', '('gas', 'flux_S2_6730.82A')_max',
#        '('gas', 'flux_S2_6730.82A')_mean', '('gas', 'flux_S2_6730.82A')_agg',
#        '('gas', 'luminosity_S2_6730.82A')_min',
#        '('gas', 'luminosity_S2_6730.82A')_max',
#        '('gas', 'luminosity_S2_6730.82A')_mean',
#        '('gas', 'luminosity_S2_6730.82A')_agg', 'Stellar Mass'],
#       dtype='object', length=285)
#    output_id                 current_time   domain_dimensions  \
# 0        304  4.247313990475821 code_time  [32.0, 32.0, 32.0]
# 1        305  4.244443006302539 code_time  [32.0, 32.0, 32.0]
# 2        306  4.241535897845871 code_time  [32.0, 32.0, 32.0]
# ...

# %%
lines=["H1_6562.80A","O1_1304.86A","O1_6300.30A","O2_3728.80A","O2_3726.10A",
       "O3_1660.81A","O3_1666.15A","O3_4363.21A","O3_4958.91A","O3_5006.84A", 
       "He2_1640.41A","C2_1335.66A","C3_1906.68A","C3_1908.73A","C4_1549.00A",
       "Mg2_2795.53A","Mg2_2802.71A","Ne3_3868.76A","Ne3_3967.47A","N5_1238.82A",
       "N5_1242.80A","N4_1486.50A","N3_1749.67A","S2_6716.44A","S2_6730.82A"]

column_list = []

for line in lines:
    field = ('gas', f'luminosity_{line}')
    column = str(field) + '_agg'
    column_list.append(column)

print(column_list)

plt.figure(figsize=(8, 6))

for i, column in enumerate(column_list):
    plt.plot(df['current_redshift'], np.log10(df[column]), linestyle='-', label=lines[i])
plt.xlabel('Redshift')
plt.ylabel('Luminosities')
#plt.title(title)
plt.grid(True)
ax = plt.gca()
ax.invert_xaxis()
plt.tight_layout()
plt.legend()
#plt.savefig("plot.png")
plt.show()
# Out:
# ["('gas', 'luminosity_H1_6562.80A')_agg", "('gas', 'luminosity_O1_1304.86A')_agg", "('gas', 'luminosity_O1_6300.30A')_agg", "('gas', 'luminosity_O2_3728.80A')_agg", "('gas', 'luminosity_O2_3726.10A')_agg", "('gas', 'luminosity_O3_1660.81A')_agg", "('gas', 'luminosity_O3_1666.15A')_agg", "('gas', 'luminosity_O3_4363.21A')_agg", "('gas', 'luminosity_O3_4958.91A')_agg", "('gas', 'luminosity_O3_5006.84A')_agg", "('gas', 'luminosity_He2_1640.41A')_agg", "('gas', 'luminosity_C2_1335.66A')_agg", "('gas', 'luminosity_C3_1906.68A')_agg", "('gas', 'luminosity_C3_1908.73A')_agg", "('gas', 'luminosity_C4_1549.00A')_agg", "('gas', 'luminosity_Mg2_2795.53A')_agg", "('gas', 'luminosity_Mg2_2802.71A')_agg", "('gas', 'luminosity_Ne3_3868.76A')_agg", "('gas', 'luminosity_Ne3_3967.47A')_agg", "('gas', 'luminosity_N5_1238.82A')_agg", "('gas', 'luminosity_N5_1242.80A')_agg", "('gas', 'luminosity_N4_1486.50A')_agg", "('gas', 'luminosity_N3_1749.67A')_agg", "('gas', 'luminosity_S2_6716.44A')_agg", "('gas',
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['current_redshift'], np.cumsum(df['Stellar Mass']), linestyle='-', label=lines[i])
plt.xlabel('Redshift')
plt.ylabel('Stellar Mass')
#plt.title(title)
plt.grid(True)
ax = plt.gca()
ax.invert_xaxis()
plt.tight_layout()
plt.legend()
#plt.savefig("plot.png")
plt.show()

# %%
# Define color and linestyle cycles
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
linestyles = ['-', '--', '-.', ':']

# Create a combined (color, linestyle) cycle
style_cycler = itertools.cycle(itertools.product(colors, linestyles))

plt.figure(figsize=(10, 6))

for i, column in enumerate(column_list):
    if column in df.columns:
        y_vals = df[column].replace(0, np.nan)
        color, linestyle = next(style_cycler)
        plt.plot(df['current_redshift'], np.log10(y_vals), linestyle=linestyle,
                 color=color, label=lines[i])

plt.xlabel('Redshift')
plt.ylabel('Luminosities')
plt.grid(True)
ax = plt.gca()
ax.invert_xaxis()
plt.tight_layout()

# Place legend to the right
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.show()

# %%
from collections import defaultdict

# Group lines by element (e.g., 'O3', 'H1', etc.)
groups = defaultdict(list)
for line in lines:
    prefix = line.split('_')[0]
    groups[prefix].append(line)

# Set up color and linestyle cycler
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
linestyles = ['-', '--', '-.', ':']
style_cycler = itertools.cycle(itertools.product(colors, linestyles))

plt.figure(figsize=(10, 6))

for group, group_lines in groups.items():
    color, linestyle = next(style_cycler)
    for i, line in enumerate(group_lines):
        column = f"('gas', 'luminosity_{line}')_agg"
        if column in df.columns:
            y_vals = df[column].replace(0, np.nan)
            # Only label the first line of the group
            label = group if i == 0 else None
            plt.plot(df['current_redshift'], np.log10(y_vals),
                     color=color, linestyle=linestyle, label=label)

plt.xlabel('Redshift')
plt.ylabel('Luminosities')
plt.grid(True)
ax = plt.gca()
ax.invert_xaxis()
plt.tight_layout()

# Show unique element legend to the right
plt.legend(title='Element', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
# TODO normalize
# response; group by response
# slow decay - diffuse gas; density dependence; recombination coeff; He fast recomb.


#SBATCH -A ricotti-prj-astr

# combine lines in images
# paper draft

# high density ionized gas - high z
# strong ionization, bursts

# share
